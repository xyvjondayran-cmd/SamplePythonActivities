# %% [markdown]
# <a href="https://colab.research.google.com/github/xyvjondayran-cmd/SamplePythonActivities/blob/main/Q1_Narra_FA1_JoandayranXeana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Revision of previous code
import math

# put needed variables
x1 = float(input("Enter x1: "))
y1 = float(input("Enter x2: "))
x2 = float(input("Enter y1: "))
y2 = float(input("Enter y2: "))
# My variable were wrong and maybe that's why it didn't work

# This will calculate the distance between the two  points
distance = math.sqrt(math.pow(x2 - x1, 2) + math.pow(y2 - y1, 2))

#Then print the distance and round it
print("The distance is", round(distance, 2))
# Out:
# Enter x1: 5
# Enter x2: 6
# Enter y1: 7
# Enter y2: 3
# The distance is 3.61
